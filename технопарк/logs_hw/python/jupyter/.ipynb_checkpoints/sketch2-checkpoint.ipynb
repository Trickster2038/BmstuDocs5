# %%
import pandas as pd

# %%
names=["ip", "1", "2", "3", "4", "url", "status", "size", "5", "6", "7"]
df = pd.read_csv("access.log", sep=" ", usecols= range(11), low_memory=False, header=None, names=names)
df = df.iloc[:,[0,5,6,7,8,9,10]]
df
# Out:
#                     ip                                                url  \
# 0       134.249.53.185  POST http://almhuette-raith.at/administrator/i...
# 1       134.249.53.185  GET http://almhuette-raith.at/administrator/in...
# 2       134.249.53.185  GET http://almhuette-raith.at/administrator/in...
# 3       134.249.53.185  POST http://almhuette-raith.at/administrator/i...
# 4       134.249.53.185  GET http://almhuette-raith.at/administrator/in...
# ...                ...                                                ...
# 225128    149.56.83.40             POST /administrator/index.php HTTP/1.1
# 225129    149.56.83.40             POST /administrator/index.php HTTP/1.1
# 225130    149.56.83.40             POST /administrator/index.php HTTP/1.1
# 225131    149.56.83.40             POST /administrator/index.php HTTP/1.1
# 225132    149.56.83.40             POST /administrator/index.php HTTP/1.1
#
#         status  size  5  6  7
# 0          200  4498  -  -  -
# 1          200  4267  -  -  -
# 2          200  4238  -  -  -
# 3          200  4498  -  -  -
# 4          200  4267  -  -  -
# ...        ...   ... .. .. ..
# 225128     200  4498  -  -  -
# 225129     200  4498  -  -  -
# 225130     200  4498  -  -  -
# 225131     200  4498  -  -  -
# 225132     200  4498  -  -  -
#
# [225133 rows x 7 columns]

# %%
total_queries = df.shape[0]
total_queries
# Out:
# 225133

# %%
df_methods_1 = df.copy()
df_methods_1["method"] = df_methods_1.apply (lambda row: row["url"].split()[0], axis=1)
df_methods_2 = pd.DataFrame(df_methods_1["method"])
df_methods_2["cnt"] = 0
df_meths = df_methods_2.groupby(by=["method"], as_index=False).count()
df_m_normal = df_meths.loc[(df_meths["method"].astype('str').str.len() < 10)]
df_m_normal
# Out:
#   method     cnt
# 0    GET  122095
# 1   HEAD     528
# 2   POST  102503
# 3    PUT       6

# %%
df_m_unnormal = df_meths.loc[(df_meths["method"].astype('str').str.len() >= 10)]
df_m_unnormal
# Out:
#                                               method  cnt
# 4  g369g=%40eval%01%28base64_decode%28%24_POST%5B...    1

# %%
df_urls = pd.DataFrame(df.iloc[:,1])
df_urls["cnt"] = 0
df_urls2 = df_urls.copy()
df_urls2["url_without_params"] = df_urls.apply (lambda row: row["url"].split()[1], axis=1)
del df_urls2["url"]
df_urls_g = df_urls2.groupby(by=["url_without_params"], as_index=False).count()
df_top_10 = df_urls_g.sort_values("cnt", ascending=False).head(10)
df_top_10
# df_urls
# Out:
#                                      url_without_params     cnt
# 443                            /administrator/index.php  103932
# 578                              /apache-log/access.log   26336
# 0                                                     /    6940
# 3871                 /templates/_system/css/general.css    4980
# 3790                                        /robots.txt    3199
# 4424  http://almhuette-raith.at/administrator/index.php    2356
# 1393                                       /favicon.ico    2201
# 4352                                      /wp-login.php    1644
# 268                                     /administrator/    1563
# 3971               /templates/jp_hotel/css/template.css    1287

# %%
df_4xx = df.query("status >= 400 and status < 500").iloc[:,0:4].sort_values("size", ascending=False).head(5)
df_4xx
# Out:
#                    ip                                                url  \
# 22924  164.132.159.94  GET /index.php%3Foption%3Dcom_content%26view%3...
# 22925  164.132.159.94  GET /index.php%3Foption%3Dcom_content%26view%3...
# 22878  164.132.159.94  GET /index.php%3Foption%3Dcom_content%26view%3...
# 22877  164.132.159.94  GET /index.php%3Foption%3Dcom_content%26view%3...
# 22927  164.132.159.94  GET /index.php%3Foption%3Dcom_content%26view%3...
#
#        status size
# 22924     404  442
# 22925     404  442
# 22878     404  442
# 22877     404  442
# 22927     404  437

# %%
df_5xx = df.query("status >= 500 and status < 600").iloc[:,[0]]
df_5xx["cnt"] = 0
df_5xx_ans = df_5xx.groupby(by=["ip"], as_index=False).count().sort_values("cnt", ascending=False).head(5)
df_5xx_ans
# Out:
#                ip  cnt
# 6   189.217.45.73  225
# 26  82.193.127.15    4
# 30  91.210.145.36    3
# 9   198.38.94.207    2
# 7    194.87.237.6    2
